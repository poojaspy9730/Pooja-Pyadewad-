# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:/Users/adity/OneDrive/Desktop/DSBDAL/Employee.csv")

# %%
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.shape
# Out:
# (4653, 9)

# %%
df.head
# Out:
# <bound method NDFrame.head of       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.Age.mean()
# Out:
# np.float64(29.393294648613796)

# %%
df.Age.mode()
# Out:
# 0    26
# Name: Age, dtype: int64

# %%
df.Age.median()
# Out:
# 28.0

# %%
df.groupby(['Age']).count()
# Out:
#      Education  JoiningYear  City  PaymentTier  Gender  EverBenched  \
# Age
# 22          49           49    49           49      49           49
# 23          48           48    48           48      48           48
# 24         385          385   385          385     385          385
# 25         418          418   418          418     418          418
# 26         645          645   645          645     645          645
# 27         625          625   625          625     625          625
# 28         630          630   630          630     630          630
# 29         230          230   230          230     230          230
# 30         220          220   220          220     220          220
# 31         125          125   125          125     125          125
# 32         132          132   132          132     132          132
# 33         124          124   124          124     124          124
# 34         136          136   136          136     136          136
# ...

# %%
df.groupby(['Gender']).count()
# Out:
#         Education  JoiningYear  City  PaymentTier   Age  EverBenched  \
# Gender
# Female       1875         1875  1875         1875  1875         1875
# Male         2778         2778  2778         2778  2778         2778
#
#         ExperienceInCurrentDomain  LeaveOrNot
# Gender
# Female                       1875        1875
# Male                         2778        2778

# %%
df[['Age' , 'ExperienceInCurrentDomain', 'LeaveOrNot']].mean()
# Out:
# Age                          29.393295
# ExperienceInCurrentDomain     2.905652
# LeaveOrNot                    0.343864
# dtype: float64

# %%
df[['Age' , 'ExperienceInCurrentDomain', 'LeaveOrNot']].mode()
# Out:
#    Age  ExperienceInCurrentDomain  LeaveOrNot
# 0   26                          2           0

# %%
df[['Age' , 'ExperienceInCurrentDomain', 'LeaveOrNot']].median()
# Out:
# Age                          28.0
# ExperienceInCurrentDomain     3.0
# LeaveOrNot                    0.0
# dtype: float64

# %%
df[['Age' , 'ExperienceInCurrentDomain', 'LeaveOrNot']].max()
# Out:
# Age                          41
# ExperienceInCurrentDomain     7
# LeaveOrNot                    1
# dtype: int64

# %%
df[['Age' , 'ExperienceInCurrentDomain', 'LeaveOrNot']].std()
# Out:
# Age                          4.826087
# ExperienceInCurrentDomain    1.558240
# LeaveOrNot                   0.475047
# dtype: float64

# %%
df2=df.groupby('Gender')

# %%
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
for Gender, Gender_f in df2:
 print(Gender)
 print(Gender_f)
# Out:
# Female
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 7     Bachelors         2016  Bangalore            3   34  Female          No
# 16    Bachelors         2014  Bangalore            3   34  Female          No
# 18    Bachelors         2015       Pune            2   30  Female          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4643  Bachelors         2013  Bangalore            3   31  Female          No
# 4644  Bachelors         2015       Pune            3   32  Female         Yes
# 4645    Masters         2017       Pune            2   31  Female          No
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
#
# ...

# %%
df2.get_group('Male')
# Out:
#       Education  JoiningYear       City  PaymentTier  Age Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34   Male          No
# 3       Masters         2016  Bangalore            3   27   Male          No
# 4       Masters         2017       Pune            3   24   Male         Yes
# 5     Bachelors         2016  Bangalore            3   22   Male          No
# 6     Bachelors         2015  New Delhi            3   38   Male          No
# ...         ...          ...        ...          ...  ...    ...         ...
# 4647  Bachelors         2016       Pune            3   30   Male          No
# 4649    Masters         2013       Pune            2   37   Male          No
# 4650    Masters         2018  New Delhi            3   27   Male          No
# 4651  Bachelors         2012  Bangalore            3   30   Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33   Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df2.get_group('Female')
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 7     Bachelors         2016  Bangalore            3   34  Female          No
# 16    Bachelors         2014  Bangalore            3   34  Female          No
# 18    Bachelors         2015       Pune            2   30  Female          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4643  Bachelors         2013  Bangalore            3   31  Female          No
# 4644  Bachelors         2015       Pune            3   32  Female         Yes
# 4645    Masters         2017       Pune            2   31  Female          No
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df["JoiningYear"].hist()
plt.show()
df[["Age","JoiningYear"]].skew()
# Out:
# Age            0.905195
# JoiningYear   -0.113462
# dtype: float64

# %%
df["Age"]
# Out:
# 0       34
# 1       28
# 2       38
# 3       27
# 4       24
#         ..
# 4648    26
# 4649    37
# 4650    27
# 4651    30
# 4652    33
# Name: Age, Length: 4653, dtype: int64
