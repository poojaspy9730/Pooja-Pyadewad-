# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("dataset.csv")

# %%
df
# Out:
#      Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join  \
# 0          71.0           81.0           65.0             94.0     2024.0
# 1          66.0           91.0           63.0             92.0     2024.0
# 2          68.0           77.0           76.0             90.0     2022.0
# 3          67.0           81.0           78.0             95.0     2020.0
# 4          80.0           84.0           78.0             84.0     2023.0
# ..          ...            ...            ...              ...        ...
# 144        77.0           86.0           78.0             77.0     2022.0
# 145         0.0           82.0           73.0             93.0     2020.0
# 146        77.0           89.0           62.0             93.0     2024.0
# 147        63.0           80.0           68.0             90.0     2024.0
# 148        71.0           77.0           72.0             93.0     2022.0
#
#      Placement_Offer
# 0                3.0
# 1                3.0
# 2                3.0
# 3                3.0
# 4                2.0
# ..               ...
# 144              2.0
# 145             10.0
# 146             10.0
# 147              3.0
# 148              3.0
#
# [149 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       143 non-null    float64
#  1   Reading_Score    143 non-null    float64
#  2   Writing_Score    144 non-null    float64
#  3   Placement_Score  139 non-null    float64
#  4   Club_Join        142 non-null    float64
#  5   Placement_Offer  144 non-null    float64
# dtypes: float64(6)
# memory usage: 7.1 KB

# %%
df.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score    Club_Join  \
# count  143.000000     143.000000     144.000000       139.000000   142.000000
# mean    69.909091      85.062937      70.131944        85.028777  2022.176056
# std     13.840087       5.953123       6.232384         5.779703     1.400604
# min      0.000000      75.000000      60.000000        75.000000  2020.000000
# 25%     64.000000      80.000000      65.000000        80.000000  2021.000000
# 50%     70.000000      86.000000      70.000000        86.000000  2022.000000
# 75%     75.000000      90.000000      76.000000        90.000000  2023.000000
# max    200.000000      95.000000      80.000000        95.000000  2024.000000
#
#        Placement_Offer
# count       144.000000
# mean          2.569444
# std           1.068643
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max          10.000000

# %%
df.isnull().sum()
# Out:
# Math_Score          6
# Reading_Score       6
# Writing_Score       5
# Placement_Score    10
# Club_Join           7
# Placement_Offer     5
# dtype: int64

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join', 'Placement_Offer'],
#       dtype='object')

# %%
x= df.Math_Score.mean()

# %%
x
# Out:
# np.float64(69.9090909090909)

# %%
df.Math_Score.fillna(x,inplace= True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_18612\354774377.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Math_Score.fillna(x,inplace= True)

# %%
df.isnull().sum()
# Out:
# Math_Score          0
# Reading_Score       6
# Writing_Score       5
# Placement_Score    10
# Club_Join           7
# Placement_Offer     5
# dtype: int64

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join', 'Placement_Offer'],
#       dtype='object')

# %%
y = df.Writing_Score.mean()

# %%
y
# Out:
# np.float64(70.13194444444444)

# %%
df.Writing_Score.fillna(y,inplace= True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_18612\649882295.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Writing_Score.fillna(y,inplace= True)

# %%
df.isnull().sum()
# Out:
# Math_Score          0
# Reading_Score       6
# Writing_Score       0
# Placement_Score    10
# Club_Join           7
# Placement_Offer     5
# dtype: int64

# %%
z = df.Reading_Score.min()

# %%
z
# Out:
# 75.0

# %%
df.Reading_Score.fillna(z,inplace= True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_18612\2468358276.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Reading_Score.fillna(z,inplace= True)

# %%
df.isnull().sum()
# Out:
# Math_Score          0
# Reading_Score       0
# Writing_Score       0
# Placement_Score    10
# Club_Join           7
# Placement_Offer     5
# dtype: int64

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join', 'Placement_Offer'],
#       dtype='object')

# %%
df.boxplot(column=['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score'])
# Out:
# <Axes: >

# %%
import numpy as np
Q1 = np.percentile(df['Math_Score'], 25)
Q3 = np.percentile(df['Math_Score'], 75)

IQR = Q3 - Q1

# %%
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Lower Limit:", lower)
print("Upper Limit:", upper)
# Out:
# Lower Limit: 47.5
# Upper Limit: 91.5

# %%
outliers = df[(df['Math_Score'] < lower) | (df['Math_Score'] > upper)]
print(outliers)
# Out:
#      Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join  \
# 141       200.0           89.0           79.0             75.0     2023.0
# 145         0.0           82.0           73.0             93.0     2020.0
#
#      Placement_Offer
# 141              2.0
# 145             10.0

# %%
df = df.drop(df[(df['Math_Score'] < lower) | 
                (df['Math_Score'] > upper)].index)

# %%
df
# Out:
#      Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join  \
# 0          71.0           81.0           65.0             94.0     2024.0
# 1          66.0           91.0           63.0             92.0     2024.0
# 2          68.0           77.0           76.0             90.0     2022.0
# 3          67.0           81.0           78.0             95.0     2020.0
# 4          80.0           84.0           78.0             84.0     2023.0
# ..          ...            ...            ...              ...        ...
# 143        67.0           92.0           72.0             92.0     2021.0
# 144        77.0           86.0           78.0             77.0     2022.0
# 146        77.0           89.0           62.0             93.0     2024.0
# 147        63.0           80.0           68.0             90.0     2024.0
# 148        71.0           77.0           72.0             93.0     2022.0
#
#      Placement_Offer
# 0                3.0
# 1                3.0
# 2                3.0
# 3                3.0
# 4                2.0
# ..               ...
# 143              3.0
# 144              2.0
# 146             10.0
# 147              3.0
# 148              3.0
#
# [147 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

df.boxplot(column=['Math_Score',
                   'Reading_Score',
                   'Writing_Score',
                   'Placement_Score'])

plt.show()
